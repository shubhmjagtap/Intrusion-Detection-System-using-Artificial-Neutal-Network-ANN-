# %%
# importing all the packages we will use in this project
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.neural_network import MLPClassifier
# %matplotlib inline

# loading the dataset and printin first five values
x_train = pd.read_csv('Train_data.csv')
x_train.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       20     2        491          0     0
# 1         0           udp       45     2        146          0     0
# 2         0          icmp       50     4          0          0     0
# 3         0          icmp       25     2        232       8153     0
# 4         0          icmp       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
#checking for number of null values
x_train.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
y_train = x_train.iloc[:,-1]
y_train
# Out:
# 0         normal
# 1         normal
# 2            dos
# 3         normal
# 4         normal
# 5            dos
# 6            dos
# 7            dos
# 8            dos
# 9            dos
# 10           dos
# 11           dos
# 12        normal
# 13           r2l
# 14           dos
# 15           dos
# 16        normal
# 17         probe
# 18        normal
# 19        normal
# 20           dos
# 21           dos
# 22        normal
# 23        normal
# 24           dos
# 25        normal
# 26           dos
# 27        normal
# 28        normal
# 29        normal
#            ...
# 125943    normal
# 125944    normal
# 125945    normal
# 125946       dos
# 125947     probe
# 125948       dos
# 125949    normal
# 125950       dos
# 125951    normal
# 125952    normal
# 125953       dos
# 125954    normal
# 125955    normal
# 125956    normal
# 125957    normal
# 125958       dos
# 125959    normal
# 125960    normal
# 125961    normal
# 125962    normal
# 125963    normal
# ...

# %%
x_train.drop(x_train.columns[[-1,]], axis=1, inplace=True)

# %%
x_train
# Out:
#         duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0              0          icmp       20     2        491          0     0
# 1              0           udp       45     2        146          0     0
# 2              0          icmp       50     4          0          0     0
# 3              0          icmp       25     2        232       8153     0
# 4              0          icmp       25     2        199        420     0
# 5              0          icmp       50     1          0          0     0
# 6              0          icmp       50     4          0          0     0
# 7              0          icmp       50     4          0          0     0
# 8              0          icmp       52     4          0          0     0
# 9              0          icmp       50     4          0          0     0
# 10             0          icmp       50     1          0          0     0
# 11             0          icmp       50     4          0          0     0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
number = LabelEncoder()
x_train['protocol_type'] = number.fit_transform(x_train['protocol_type'].astype('str'))
x_train
# Out:
#         duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0              0              0       20     2        491          0     0
# 1              0              2       45     2        146          0     0
# 2              0              0       50     4          0          0     0
# 3              0              0       25     2        232       8153     0
# 4              0              0       25     2        199        420     0
# 5              0              0       50     1          0          0     0
# 6              0              0       50     4          0          0     0
# 7              0              0       50     4          0          0     0
# 8              0              0       52     4          0          0     0
# 9              0              0       50     4          0          0     0
# 10             0              0       50     1          0          0     0
# ...

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(30,30,30), random_state=1)

# %%
clf.fit(x_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(30, 30, 30), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
x_test = pd.read_csv('test_data.csv')
x_test.head()
# Out:
#    Unnamed: 0  duration protocol_type  service  flag  src_bytes  dst_bytes  \
# 0         202         0          icmp       25     4          0          0
# 1         768         0          icmp       25     2        312       1856
# 2        3753         0          icmp       25     2        245       2058
# 3       20087         0          icmp       25     2        298       1267
# 4       16159         0          icmp       20     2        740          0
#
#    land  wrong_fragment  urgent  ...  dst_host_srv_count  \
# 0     0               0       0  ...                 255
# 1     0               0       0  ...                 254
# 2     0               0       0  ...                 255
# 3     0               0       0  ...                 255
# 4     0               0       0  ...                  19
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    1.00                    0.00
# 1                    1.00                    0.00
# ...

# %%
x_test
# Out:
#       Unnamed: 0  duration protocol_type  service  flag  src_bytes  dst_bytes  \
# 0            202         0          icmp       25     4          0          0
# 1            768         0          icmp       25     2        312       1856
# 2           3753         0          icmp       25     2        245       2058
# 3          20087         0          icmp       25     2        298       1267
# 4          16159         0          icmp       20     2        740          0
# 5          18012         0          icmp       25     2        304      16414
# 6          15066         0          icmp       29     3          0         44
# 7           6541         0          icmp       25     5      42340       7300
# 8          10031         4          icmp       48     2         32         93
# 9          14225         0          icmp       25     2        249       5656
# 10         11041         0          icmp       50     1          0          0
# ...

# %%
y_test = x_test.iloc[:,-1]
y_test
# Out:
# 0          dos
# 1       normal
# 2       normal
# 3       normal
# 4       normal
# 5       normal
# 6        probe
# 7          dos
# 8          r2l
# 9       normal
# 10         dos
# 11      normal
# 12      normal
# 13         dos
# 14         dos
# 15       probe
# 16      normal
# 17      normal
# 18         r2l
# 19         dos
# 20         dos
# 21      normal
# 22         r2l
# 23      normal
# 24      normal
# 25         dos
# 26      normal
# 27       probe
# 28         dos
# 29      normal
#          ...
# 9970       r2l
# 9971       r2l
# 9972       dos
# 9973     probe
# 9974    normal
# 9975     probe
# 9976       dos
# 9977     probe
# 9978       r2l
# 9979       dos
# 9980       dos
# 9981       dos
# 9982       r2l
# 9983       r2l
# 9984     probe
# 9985     probe
# 9986       dos
# 9987       dos
# 9988       dos
# 9989       dos
# 9990       r2l
# 9991    normal
# 9992       dos
# 9993    normal
# 9994    normal
# 9995    normal
# 9996    normal
# ...

# %%
x_test['protocol_type'] = number.fit_transform(x_test['protocol_type'].astype('str'))
x_test
# Out:
#       Unnamed: 0  duration  protocol_type  service  flag  src_bytes  \
# 0            202         0              0       25     4          0
# 1            768         0              0       25     2        312
# 2           3753         0              0       25     2        245
# 3          20087         0              0       25     2        298
# 4          16159         0              0       20     2        740
# 5          18012         0              0       25     2        304
# 6          15066         0              0       29     3          0
# 7           6541         0              0       25     5      42340
# 8          10031         4              0       48     2         32
# 9          14225         0              0       25     2        249
# 10         11041         0              0       50     1          0
# 11          2857         0              0       25     2        208
# 12          4471         0              0       25     2        225
# ...

# %%
x_test.drop(x_test.columns[[-1,]], axis=1, inplace=True)
x_test
# Out:
#       Unnamed: 0  duration  protocol_type  service  flag  src_bytes  \
# 0            202         0              0       25     4          0
# 1            768         0              0       25     2        312
# 2           3753         0              0       25     2        245
# 3          20087         0              0       25     2        298
# 4          16159         0              0       20     2        740
# 5          18012         0              0       25     2        304
# 6          15066         0              0       29     3          0
# 7           6541         0              0       25     5      42340
# 8          10031         4              0       48     2         32
# 9          14225         0              0       25     2        249
# 10         11041         0              0       50     1          0
# 11          2857         0              0       25     2        208
# 12          4471         0              0       25     2        225
# ...

# %%
x_test = x_test.loc[:, ~x_test.columns.str.contains('^Unnamed')]
x_test
# Out:
#       duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0            0              0       25     4          0          0     0
# 1            0              0       25     2        312       1856     0
# 2            0              0       25     2        245       2058     0
# 3            0              0       25     2        298       1267     0
# 4            0              0       20     2        740          0     0
# 5            0              0       25     2        304      16414     0
# 6            0              0       29     3          0         44     0
# 7            0              0       25     5      42340       7300     0
# 8            4              0       48     2         32         93     0
# 9            0              0       25     2        249       5656     0
# 10           0              0       50     1          0          0     0
# 11           0              0       25     2        208        277     0
# ...

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          dos       0.84      0.63      0.72      3332
#       normal       0.59      0.54      0.56      4329
#        probe       0.01      0.04      0.02      1053
#          r2l       0.17      0.11      0.13      1199
#          u2r       0.00      0.00      0.00        87
#
#     accuracy                           0.46     10000
#    macro avg       0.32      0.26      0.29     10000
# weighted avg       0.56      0.46      0.50     10000
# C:\Users\shubh\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
